# %%
import gym
import gym_coverage
import random
import numpy as np
import tensorflow as tf

from CNNDQNAgent import CNNDQNAgent
from collections import deque

from matplotlib import pyplot as plt

seed = 0
np.random.seed(seed)
random.seed(seed)

# %%
env = gym.make('Coverage-v1')
env.seed(seed)
N_F_pos = env.observation_space.spaces[0].n
N_F_map = env.observation_space.spaces[1].shape[0]
N_F = N_F_pos + N_F_map
N_A = env.action_space.n
agent = CNNDQNAgent(N_F_pos, N_F_map, N_A, epsilon_decay=0.9999, epsilon_min=0.10, memory_mode='NORMAL', target_mode='DQN', batch_size=64)
agent.restore_model(path="model/cnn_dqn_8_model.ckpt")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <type 'numpy.float32'>. Please provide explicit dtype.
# INFO:tensorflow:Restoring parameters from model/cnn_dqn_8_model.ckpt
# Model restored.

# %%
import time
max_t = 80
avg_return_list = deque(maxlen=10)
avg_loss_list = deque(maxlen=10)
for i in range(500000):
    obs = env.reset()
    obs = np.concatenate((np.eye(64)[obs[0]], obs[1].flatten()))
    done = False
    total_reward = 0
    total_loss = 0
    #env.render()
    #time.sleep(0.5)
    for t in range(max_t):
        action = agent.get_action(np.reshape(obs, (1, -1)))
        next_obs, reward, done, info = env.step(action)
        next_obs = np.concatenate((np.eye(64)[next_obs[0]], next_obs[1].flatten()))
        agent.add_experience(obs, action, reward, next_obs, done)
        
        loss = agent.train_model()
        agent.update_memory(t, max_t)
        agent.update_policy()
        #env.render()
        #time.sleep(0.5)
        obs = next_obs
        total_reward += reward
        total_loss += loss
        if done:
            break
            
    agent.update_target()
    avg_return_list.append(total_reward)
    avg_loss_list.append(total_loss)
    
    if (i%1000)==0:
        print('{} loss : {:.3f}, return : {:.3f}, eps : {:.3f}'.format(i, np.mean(avg_loss_list), np.mean(avg_return_list), agent.epsilon))
#agent.save_model(path="model/coverage_6_model_new.ckpt")
#agent.restore_model(path="model/coverage_6_model.ckpt")
# Out:
# 0 loss : nan, return : -281.000, eps : 1.000
# 1000 loss : 1803.114, return : -185.100, eps : 0.599
# 2000 loss : 517.001, return : -177.400, eps : 0.164
# 3000 loss : 768.530, return : -24.000, eps : 0.100
# full cover
# 4000 loss : 557.296, return : -3.500, eps : 0.100
# 5000 loss : 318.740, return : -93.200, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 6000 loss : 2638.268, return : -25.100, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 7000 loss : 616.783, return : -155.100, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 8000 loss : 2340.021, return : -34.600, eps : 0.100
# full cover
# full cover
# full cover
# 9000 loss : 432.224, return : -27.700, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 10000 loss : 1347.923, return : -43.800, eps : 0.100
# 11000 loss : 452.210, return : -73.200, eps : 0.100
# full cover
# 12000 loss : 629.057, return : 5.000, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 13000 loss : 3782.439, return : 212.000, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 14000 loss : 706.048, return : -79.100, eps : 0.100
# full cover
# full cover
# full cover
# 15000 loss : 1616.655, return : 29.800, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 16000 loss : 1955.592, return : -49.600, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# 17000 loss : 432.299, return : -107.800, eps : 0.100
# full cover
# 18000 loss : 306.824, return : -143.900, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 19000 loss : 2073.393, return : -73.800, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# 20000 loss : 763.680, return : 9.100, eps : 0.100
# full cover
# full cover
# 21000 loss : 636.104, return : -100.300, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# 22000 loss : 1006.058, return : -59.600, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# 23000 loss : 1205.885, return : -45.100, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 24000 loss : 1220.987, return : 208.600, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# 25000 loss : 486.996, return : 12.400, eps : 0.100
# full cover
# full cover
# full cover
# 26000 loss : 414.348, return : 94.900, eps : 0.100
# full cover
# full cover
# full cover
# 27000 loss : 1266.365, return : 87.200, eps : 0.100
# full cover
# full cover
# full cover
# 28000 loss : 357.672, return : -50.200, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 29000 loss : 734.078, return : -43.000, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# 30000 loss : 426.311, return : -213.700, eps : 0.100
# full cover
# 31000 loss : 758.192, return : -113.300, eps : 0.100
# full cover
# 32000 loss : 2277.765, return : -66.500, eps : 0.100
# full cover
# full cover
# full cover
# 33000 loss : 2886.568, return : 123.500, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 34000 loss : 4117.940, return : 122.700, eps : 0.100
# 35000 loss : 483.308, return : -50.300, eps : 0.100
# full cover
# full cover
# full cover
# 36000 loss : 1740.216, return : 30.100, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# 37000 loss : 1099.550, return : -43.300, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 38000 loss : 2270.315, return : -111.500, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# 39000 loss : 1631.976, return : 74.400, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 40000 loss : 2445.190, return : 30.100, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 41000 loss : 1410.561, return : 83.500, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 42000 loss : 749.797, return : -37.400, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 43000 loss : 783.235, return : 49.100, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 44000 loss : 1984.156, return : -20.100, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 45000 loss : 1896.909, return : -87.500, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 46000 loss : 901.788, return : -66.300, eps : 0.100
# full cover
# full cover
# full cover
# 47000 loss : 477.846, return : -71.800, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# 48000 loss : 647.118, return : -47.900, eps : 0.100
# 49000 loss : 238.124, return : -176.800, eps : 0.100
# full cover
# full cover
# full cover
# 50000 loss : 509.505, return : -138.800, eps : 0.100
# full cover
# 51000 loss : 586.310, return : 187.000, eps : 0.100
# full cover
# 52000 loss : 355.734, return : -131.000, eps : 0.100
# full cover
# full cover
# full cover
# 53000 loss : 189.341, return : -177.000, eps : 0.100
# full cover
# 54000 loss : 631.962, return : -66.300, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 55000 loss : 2661.276, return : -72.300, eps : 0.100
# full cover
# full cover
# 56000 loss : 593.531, return : -42.300, eps : 0.100
# full cover
# full cover
# 57000 loss : 426.235, return : -138.600, eps : 0.100
# 58000 loss : 356.452, return : -123.900, eps : 0.100
# 59000 loss : 479.541, return : -2.000, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# 60000 loss : 666.671, return : -5.200, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 61000 loss : 386.530, return : -6.800, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# 62000 loss : 819.848, return : -107.900, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 63000 loss : 2213.421, return : -7.200, eps : 0.100
# full cover
# full cover
# full cover
# 64000 loss : 1040.637, return : 176.900, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 65000 loss : 3227.172, return : 66.000, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 66000 loss : 2874.784, return : -25.700, eps : 0.100
# full cover
# full cover
# 67000 loss : 449.870, return : -37.300, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 68000 loss : 2958.539, return : -100.400, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 69000 loss : 1570.387, return : 244.400, eps : 0.100
# full cover
# full cover
# 70000 loss : 504.669, return : 23.400, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# 71000 loss : 1166.463, return : -152.900, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# 72000 loss : 498.514, return : -151.600, eps : 0.100
# full cover
# full cover
# full cover
# 73000 loss : 644.429, return : 136.200, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# 74000 loss : 1444.712, return : -16.700, eps : 0.100
# full cover
# full cover
# 75000 loss : 1286.576, return : 29.900, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 76000 loss : 3376.020, return : 55.900, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 77000 loss : 1362.301, return : 7.300, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 78000 loss : 2691.679, return : 13.500, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 79000 loss : 2456.228, return : 117.600, eps : 0.100
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover

# %%
agent.save_model(path="model/cnn_dqn_8_model.ckpt")
max_t = 50
for i in range(100):
    obs = env.reset()
    obs = np.concatenate((np.eye(64)[obs[0]], obs[1].flatten()))
    done = False
    total_reward = 0
    env.render()
    time.sleep(0.25)
    for t in range(max_t):
        action = agent.get_action(np.reshape(obs, (1, -1)))
        next_obs, reward, done, info = env.step(action)
        
        next_obs = np.concatenate((np.eye(64)[next_obs[0]], next_obs[1].flatten()))
        
        obs = next_obs
        total_reward += reward
        env.render()
        time.sleep(0.25)
        if done:
            break
    print(total_reward)
