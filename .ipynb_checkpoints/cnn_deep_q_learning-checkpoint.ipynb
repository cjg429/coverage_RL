# %%
import gym
import gym_coverage
import random
import numpy as np
import tensorflow as tf

from CNNDQNAgent import CNNDQNAgent
from collections import deque

from matplotlib import pyplot as plt

seed = 0
np.random.seed(seed)
random.seed(seed)

# %%
env = gym.make('Coverage-v1')
env.seed(seed)
N_F_pos = env.observation_space.spaces[0].n
N_F_map = env.observation_space.spaces[1].shape[0]
N_F = N_F_pos + N_F_map
N_A = env.action_space.n
agent = CNNDQNAgent(N_F_pos, N_F_map, N_A, epsilon_decay= 0.9999, memory_mode='NORMAL', target_mode='DQN', batch_size=64)
agent.restore_model(path="model/coverage_8_cnn_dqn_model.ckpt")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <type 'numpy.float32'>. Please provide explicit dtype.
# INFO:tensorflow:Restoring parameters from model/coverage_8_cnn_dqn_model.ckpt
# Model restored.

# %%
import time
max_t = 80
avg_return_list = deque(maxlen=10)
avg_loss_list = deque(maxlen=10)
for i in range(500000):
    obs = env.reset()
    obs = np.concatenate((np.eye(64)[obs[0]], obs[1].flatten()))
    done = False
    total_reward = 0
    total_loss = 0
    #env.render()
    #time.sleep(0.5)
    for t in range(max_t):
        action = agent.get_action(np.reshape(obs, (1, -1)))
        next_obs, reward, done, info = env.step(action)
        next_obs = np.concatenate((np.eye(64)[next_obs[0]], next_obs[1].flatten()))
        agent.add_experience(obs, action, reward, next_obs, done)
        
        loss = agent.train_model()
        agent.update_memory(t, max_t)
        agent.update_policy()
        #env.render()
        #time.sleep(0.5)
        obs = next_obs
        total_reward += reward
        total_loss += loss
        if done:
            break
            
    agent.update_target()
    avg_return_list.append(total_reward)
    avg_loss_list.append(total_loss)
    
    if (i%1000)==0:
        print('{} loss : {:.3f}, return : {:.3f}, eps : {:.3f}'.format(i, np.mean(avg_loss_list), np.mean(avg_return_list), agent.epsilon))
#agent.save_model(path="model/coverage_6_model_new.ckpt")
#agent.restore_model(path="model/coverage_6_model.ckpt")
# Out:
# 0 loss : nan, return : -281.000, eps : 1.000
# 1000 loss : 936.955, return : -247.200, eps : 0.590
# 2000 loss : 1411.262, return : -85.600, eps : 0.148
# full cover
# 3000 loss : 1013.754, return : 390.400, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 4000 loss : 837.383, return : 116.400, eps : 0.010
# 5000 loss : 584.441, return : 33.500, eps : 0.010
# full cover
# full cover
# full cover
# 6000 loss : 864.282, return : 358.900, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 7000 loss : 738.695, return : 360.300, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 8000 loss : 704.682, return : 227.900, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 9000 loss : 841.397, return : 332.900, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# 10000 loss : 624.127, return : 372.900, eps : 0.010
# full cover
# 11000 loss : 650.306, return : 116.000, eps : 0.010
# 12000 loss : 710.975, return : 98.500, eps : 0.010
# 13000 loss : 735.678, return : 274.900, eps : 0.010
# full cover
# 14000 loss : 737.413, return : 172.900, eps : 0.010
# full cover
# full cover
# full cover
# 15000 loss : 678.961, return : 145.900, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 16000 loss : 606.147, return : 244.500, eps : 0.010
# full cover
# 17000 loss : 556.397, return : 161.500, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 18000 loss : 906.292, return : 127.700, eps : 0.010
# full cover
# full cover
# 19000 loss : 590.558, return : 271.800, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 20000 loss : 723.333, return : 186.300, eps : 0.010
# full cover
# 21000 loss : 708.292, return : 127.900, eps : 0.010
# full cover
# full cover
# 22000 loss : 634.196, return : 321.100, eps : 0.010
# full cover
# full cover
# full cover
# 23000 loss : 567.717, return : 169.100, eps : 0.010
# 24000 loss : 840.165, return : 118.900, eps : 0.010
# full cover
# 25000 loss : 1910.909, return : 34.200, eps : 0.010
# 26000 loss : 724.439, return : 144.300, eps : 0.010
# 27000 loss : 619.674, return : 192.100, eps : 0.010
# 28000 loss : 720.738, return : 88.000, eps : 0.010
# 29000 loss : 917.040, return : 151.100, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 30000 loss : 1259.781, return : 431.000, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 31000 loss : 1522.499, return : 153.100, eps : 0.010
# full cover
# 32000 loss : 913.509, return : 160.100, eps : 0.010
# 33000 loss : 1013.396, return : 195.100, eps : 0.010
# 34000 loss : 830.382, return : 254.300, eps : 0.010
# 35000 loss : 676.446, return : 220.200, eps : 0.010
# 36000 loss : 705.464, return : 99.700, eps : 0.010
# full cover
# full cover
# 37000 loss : 678.080, return : 74.800, eps : 0.010
# 38000 loss : 800.465, return : -1.500, eps : 0.010
# full cover
# 39000 loss : 742.975, return : 209.200, eps : 0.010
# full cover
# 40000 loss : 1336.418, return : 270.700, eps : 0.010
# 41000 loss : 648.898, return : 172.400, eps : 0.010
# full cover
# 42000 loss : 981.426, return : 150.700, eps : 0.010
# full cover
# full cover
# 43000 loss : 725.758, return : 224.000, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 44000 loss : 886.139, return : 21.200, eps : 0.010
# full cover
# 45000 loss : 844.496, return : 158.900, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 46000 loss : 1100.313, return : 129.400, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 47000 loss : 1317.984, return : 110.300, eps : 0.010
# 48000 loss : 848.926, return : 36.800, eps : 0.010
# 49000 loss : 522.937, return : 211.300, eps : 0.010
# 50000 loss : 581.366, return : 114.700, eps : 0.010
# 51000 loss : 735.438, return : 221.500, eps : 0.010
# full cover
# full cover
# full cover
# 52000 loss : 1918.872, return : 313.400, eps : 0.010
# 53000 loss : 946.204, return : -16.200, eps : 0.010
# full cover
# full cover
# full cover
# 54000 loss : 822.950, return : 135.900, eps : 0.010
# 55000 loss : 707.754, return : 33.300, eps : 0.010
# 56000 loss : 715.727, return : 218.900, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 57000 loss : 1299.997, return : 76.100, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 58000 loss : 1345.724, return : 57.300, eps : 0.010
# 59000 loss : 704.785, return : 63.500, eps : 0.010
# 60000 loss : 829.478, return : 57.600, eps : 0.010
# 61000 loss : 716.401, return : 290.400, eps : 0.010
# 62000 loss : 734.665, return : 13.600, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 63000 loss : 617.083, return : 141.600, eps : 0.010
# 64000 loss : 985.121, return : 246.800, eps : 0.010
# 65000 loss : 896.762, return : 155.200, eps : 0.010
# 66000 loss : 871.824, return : 201.400, eps : 0.010
# 67000 loss : 752.742, return : 93.700, eps : 0.010
# 68000 loss : 1163.733, return : 297.600, eps : 0.010
# 69000 loss : 922.084, return : 133.500, eps : 0.010
# full cover
# full cover
# full cover
# 70000 loss : 1173.581, return : 178.800, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 71000 loss : 1141.319, return : 222.700, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 72000 loss : 2523.919, return : 268.900, eps : 0.010
# full cover
# full cover
# 73000 loss : 876.094, return : 149.000, eps : 0.010
# full cover
# full cover
# full cover
# 74000 loss : 843.709, return : 111.700, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# 75000 loss : 1972.954, return : 302.300, eps : 0.010
# 76000 loss : 897.627, return : 6.200, eps : 0.010
# full cover
# 77000 loss : 1092.035, return : 278.700, eps : 0.010
# full cover
# full cover
# 78000 loss : 789.014, return : 120.600, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# 79000 loss : 1081.235, return : 81.600, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 80000 loss : 1154.906, return : 191.600, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 81000 loss : 815.622, return : 80.400, eps : 0.010
# 82000 loss : 1190.043, return : 190.100, eps : 0.010
# 83000 loss : 1300.927, return : 334.400, eps : 0.010
# 84000 loss : 1800.881, return : 161.900, eps : 0.010
# 85000 loss : 1031.649, return : 89.400, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# 86000 loss : 992.150, return : 88.600, eps : 0.010
# 87000 loss : 700.536, return : 142.800, eps : 0.010
# 88000 loss : 764.630, return : 9.500, eps : 0.010
# full cover
# full cover
# 89000 loss : 1520.505, return : 86.800, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 90000 loss : 903.490, return : 114.000, eps : 0.010
# full cover
# full cover
# 91000 loss : 1162.295, return : 171.600, eps : 0.010
# full cover
# 92000 loss : 1562.717, return : 402.500, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 93000 loss : 953.316, return : 109.000, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 94000 loss : 884.291, return : 152.100, eps : 0.010
# full cover
# 95000 loss : 747.512, return : 183.700, eps : 0.010
# full cover
# 96000 loss : 667.942, return : 219.800, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 97000 loss : 723.053, return : 41.800, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 98000 loss : 916.240, return : 713.500, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 99000 loss : 1352.487, return : 75.900, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 100000 loss : 1405.858, return : 323.400, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 101000 loss : 807.929, return : 312.700, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 102000 loss : 2411.000, return : 99.100, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 103000 loss : 648.508, return : 360.600, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 104000 loss : 611.061, return : -21.300, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 105000 loss : 615.009, return : 136.900, eps : 0.010
# 106000 loss : 700.564, return : 20.800, eps : 0.010
# 107000 loss : 523.422, return : 15.800, eps : 0.010
# full cover
# 108000 loss : 818.874, return : 285.000, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# full cover
# 109000 loss : 3847.180, return : 124.500, eps : 0.010
# full cover
# full cover
# full cover
# full cover
# full cover
# 110000 loss : 950.937, return : 49.400, eps : 0.010
# 111000 loss : 876.384, return : 235.100, eps : 0.010
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bf0fb8837618> in <module>()
#      12     #time.sleep(0.5)
#      13     for t in range(max_t):
# ---> 14         action = agent.get_action(np.reshape(obs, (1, -1)))
#      15         next_obs, reward, done, info = env.step(action)
#      16         next_obs = np.concatenate((np.eye(64)[next_obs[0]], next_obs[1].flatten()))
#
# /home/cjg429/Desktop/coverage_RL/CNNDQNAgent.pyc in get_action(self, obs)
#     151             return random.randint(0, self.n_action - 1)
#     152         else:
# --> 153             q_value = self.get_prediction(obs)
#     154             return np.argmax(q_value[0])
#     155
#
# /home/cjg429/Desktop/coverage_RL/CNNDQNAgent.pyc in get_prediction(self, obs)
#     143         pos_obs = obs[:, 0:self.pos_dim]
#     144         map_obs = obs[:, self.pos_dim:obs.shape[1]].reshape((-1, self.map_dim, self.map_dim, 1))
# --> 145         q_value = self.sess.run(self.q_predict, feed_dict={self.pos_ph:pos_obs, self.map_ph:map_obs})
#     146         return q_value
#     147
#
# /home/cjg429/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/cjg429/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/cjg429/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/cjg429/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/cjg429/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
agent.save_model(path="model/cnn_dqn_8_model.ckpt")
max_t = 50
for i in range(100):
    obs = env.reset()
    obs = np.concatenate((np.eye(64)[obs[0]], obs[1].flatten()))
    done = False
    total_reward = 0
    env.render()
    time.sleep(0.25)
    for t in range(max_t):
        action = agent.get_action(np.reshape(obs, (1, -1)))
        next_obs, reward, done, info = env.step(action)
        
        next_obs = np.concatenate((np.eye(64)[next_obs[0]], next_obs[1].flatten()))
        
        obs = next_obs
        total_reward += reward
        env.render()
        time.sleep(0.25)
        if done:
            break
    print(total_reward)
